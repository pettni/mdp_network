# %%
import numpy as np
import matplotlib.pyplot as plt

from planner import *
from prob_gradual import get_prob

np.random.seed(4)
prob = get_prob()
# Out:
# `polytope` failed to import `cvxopt.glpk`.
# will use `scipy.optimize.linprog`

# %%
ax = plt.gca()
plot_problem(prob, ax)
plt.show()

# %%
rob_pol = plan_mission(prob)

uav_pol = plan_exploration(prob, rob_pol)
# Out:
# finished after 19.38s and 21 iterations
# warning: could not place 40 nodes
# finished after 0.03s and 9 iterations

# %%
plot_value_rob(rob_pol, prob)
# Out:
# success probability: 0.7980198264122009

# %%
plot_value_uav(uav_pol, prob)
# Out:
# success value: 18.5736238744166
